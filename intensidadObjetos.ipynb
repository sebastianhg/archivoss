# %%
import cv2
import numpy as np
import pandas as pd
import os
from skimage import measure

def imprimir_propiedades_objeto(objeto):
    print("Objeto", objeto["id"])
    print("Intensidad:", objeto["intensidad"])
    print("\n")

def aumentar_color(imagen, brillo=0, contraste=1.0):
    # Aplicar el ajuste de brillo y contraste a la imagen
    imagen_aumentada = cv2.convertScaleAbs(imagen, alpha=contraste, beta=brillo)
    return imagen_aumentada

# Ruta de la imagen
ruta_imagen = '/home/sebastian/Documentos/analisisNETCDF/datosGraficados/2022-01-02.png'

# Verificar si la imagen existe en la ruta especificada
if not os.path.exists(ruta_imagen):
    print(f"La imagen no se encuentra en la ruta especificada: {ruta_imagen}")
else:
    # Cargar la imagen
    imagen = cv2.imread(ruta_imagen)

    # Aumentar el color de la imagen
    imagen_aumentada = aumentar_color(imagen, brillo=0, contraste=1.5)

    # Obtener las dimensiones de la imagen
    alto, ancho, _ = imagen_aumentada.shape

    # Definir el centro de la imagen
    centro_x = ancho // 2
    centro_y = alto // 2

    # Resto del código para el análisis de contornos y guardar los datos en un archivo CSV o Excel
    # ...

    # Imprimir las propiedades de los objetos encontrados
    for objeto in propiedades_objetos:
        imprimir_propiedades_objeto(objeto)
# Out:
# Objeto 1
# Intensidad: 249.20261437908496
#
#
# Objeto 2
# Intensidad: 255.0
#
#
# Objeto 3
# Intensidad: 255.0
#
#
# Objeto 4
# Intensidad: 252.57740529366828
#
#
# Objeto 5
# Intensidad: 255.0
#
#
# Objeto 6
# Intensidad: 255.0
#
#
# Objeto 7
# Intensidad: 255.0
#
#
# Objeto 8
# Intensidad: 252.76568673937095
#
#
# Objeto 9
# Intensidad: 255.0
#
#
# Objeto 10
# Intensidad: 254.04040404040404
#
#
# Objeto 11
# Intensidad: 252.14161669165418
#
#
# Objeto 12
# Intensidad: 250.875
#
#
# Objeto 13
# Intensidad: 248.05926315789475
